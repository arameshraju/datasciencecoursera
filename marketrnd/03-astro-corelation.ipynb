# %%
# install  all dependencies in requirements.txt
import subprocess
subprocess.check_call(['pip', 'install', '-r', 'requirements.txt'])

print ("All dependencies have been installed successfully.")
# Out:
# All dependencies have been installed successfully.

# %%
print(" Data Anlytics Project ")
# Out:
#  Data Anlytics Project

# %%
import pandas as pd
import numpy as np

# load spc_astro_data.csv
spx_dates_df = pd.read_csv('spx_astro_data.csv')
# make data as index 
spx_dates_df.set_index('Date', inplace=True)
# if value  > 0 then 1 else 0
spx_dates_df['change_pc']= np.where(spx_dates_df['change_pc']>0,1,0)
spx_dates_df.head()
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 1928-01-03 00:00:00-05:00  17.760000  17.760000  17.760000  17.760000       0
# 1928-01-04 00:00:00-05:00  17.719999  17.719999  17.719999  17.719999       0
# 1928-01-05 00:00:00-05:00  17.549999  17.549999  17.549999  17.549999       0
# 1928-01-06 00:00:00-05:00  17.660000  17.660000  17.660000  17.660000       0
# 1928-01-09 00:00:00-05:00  17.500000  17.500000  17.500000  17.500000       0
#
#                            change_pc  Ascendant     Sun_Sign Moon_Sign  \
# Date
# 1928-01-03 00:00:00-05:00          1  Capricorn  Sagittarius    Taurus
# 1928-01-04 00:00:00-05:00          0  Capricorn  Sagittarius    Taurus
# 1928-01-05 00:00:00-05:00          0  Capricorn  Sagittarius    Taurus
# 1928-01-06 00:00:00-05:00          1   Aquarius  Sagittarius    Gemini
# 1928-01-09 00:00:00-05:00          0   Aquarius  Sagittarius    Cancer
#
#                              Mars_Sign Mercury_Sign Jupiter_Sign Venus_Sign  \
# Date
# 1928-01-03 00:00:00-05:00      Scorpio  Sagittarius       Pisces    Scorpio
# 1928-01-04 00:00:00-05:00      Scorpio  Sagittarius       Pisces    Scorpio
# 1928-01-05 00:00:00-05:00      Scorpio  Sagittarius       Pisces    Scorpio
# 1928-01-06 00:00:00-05:00      Scorpio  Sagittarius       Pisces    Scorpio
# 1928-01-09 00:00:00-05:00  Sagittarius  Sagittarius       Pisces    Scorpio
#
#                           Saturn_Sign Rahu_Sign Ketu_Sign
# Date
# 1928-01-03 00:00:00-05:00     Scorpio    Taurus   Scorpio
# 1928-01-04 00:00:00-05:00     Scorpio    Taurus   Scorpio
# 1928-01-05 00:00:00-05:00     Scorpio    Taurus   Scorpio
# 1928-01-06 00:00:00-05:00     Scorpio    Taurus   Scorpio
# 1928-01-09 00:00:00-05:00     Scorpio    Taurus   Scorpio

# %%
import pandas as pd

dfn= spx_dates_df.copy()
SIGNS = [
    'Aries', 'Taurus', 'Gemini', 'Cancer', 'Leo', 'Virgo',
    'Libra', 'Scorpio', 'Sagittarius', 'Capricorn', 'Aquarius', 'Pisces'
]
# create a map for Moon_Sign to numerical values
dfn['Ascendant'] = dfn['Ascendant'].apply(lambda x: SIGNS.index(x))

dfn['Sun_Sign'] = dfn['Sun_Sign'].apply(lambda x: SIGNS.index(x))
dfn['Moon_Sign'] = dfn['Moon_Sign'].apply(lambda x: SIGNS.index(x))
dfn['Mars_Sign'] = dfn['Mars_Sign'].apply(lambda x: SIGNS.index(x))
dfn['Mercury_Sign'] = dfn['Mercury_Sign'].apply(lambda x: SIGNS.index(x))
dfn['Jupiter_Sign'] = dfn['Jupiter_Sign'].apply(lambda x: SIGNS.index(x))
dfn['Venus_Sign'] = dfn['Venus_Sign'].apply(lambda x: SIGNS.index(x))
dfn['Saturn_Sign'] = dfn['Saturn_Sign'].apply(lambda x: SIGNS.index(x))
dfn['Rahu_Sign'] = dfn['Rahu_Sign'].apply(lambda x: SIGNS.index(x))
dfn['Ketu_Sign'] = dfn['Ketu_Sign'].apply(lambda x: SIGNS.index(x))

dfn.head()
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 1928-01-03 00:00:00-05:00  17.760000  17.760000  17.760000  17.760000       0
# 1928-01-04 00:00:00-05:00  17.719999  17.719999  17.719999  17.719999       0
# 1928-01-05 00:00:00-05:00  17.549999  17.549999  17.549999  17.549999       0
# 1928-01-06 00:00:00-05:00  17.660000  17.660000  17.660000  17.660000       0
# 1928-01-09 00:00:00-05:00  17.500000  17.500000  17.500000  17.500000       0
#
#                            change_pc  Ascendant  Sun_Sign  Moon_Sign  \
# Date
# 1928-01-03 00:00:00-05:00          1          9         8          1
# 1928-01-04 00:00:00-05:00          0          9         8          1
# 1928-01-05 00:00:00-05:00          0          9         8          1
# 1928-01-06 00:00:00-05:00          1         10         8          2
# 1928-01-09 00:00:00-05:00          0         10         8          3
#
#                            Mars_Sign  Mercury_Sign  Jupiter_Sign  Venus_Sign  \
# Date
# 1928-01-03 00:00:00-05:00          7             8            11           7
# 1928-01-04 00:00:00-05:00          7             8            11           7
# 1928-01-05 00:00:00-05:00          7             8            11           7
# 1928-01-06 00:00:00-05:00          7             8            11           7
# 1928-01-09 00:00:00-05:00          8             8            11           7
#
#                            Saturn_Sign  Rahu_Sign  Ketu_Sign
# Date
# 1928-01-03 00:00:00-05:00            7          1          7
# 1928-01-04 00:00:00-05:00            7          1          7
# 1928-01-05 00:00:00-05:00            7          1          7
# 1928-01-06 00:00:00-05:00            7          1          7
# 1928-01-09 00:00:00-05:00            7          1          7

# %%
df= spx_dates_df.copy()
df.head()
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 1928-01-03 00:00:00-05:00  17.760000  17.760000  17.760000  17.760000       0
# 1928-01-04 00:00:00-05:00  17.719999  17.719999  17.719999  17.719999       0
# 1928-01-05 00:00:00-05:00  17.549999  17.549999  17.549999  17.549999       0
# 1928-01-06 00:00:00-05:00  17.660000  17.660000  17.660000  17.660000       0
# 1928-01-09 00:00:00-05:00  17.500000  17.500000  17.500000  17.500000       0
#
#                            change_pc  Ascendant     Sun_Sign Moon_Sign  \
# Date
# 1928-01-03 00:00:00-05:00          1  Capricorn  Sagittarius    Taurus
# 1928-01-04 00:00:00-05:00          0  Capricorn  Sagittarius    Taurus
# 1928-01-05 00:00:00-05:00          0  Capricorn  Sagittarius    Taurus
# 1928-01-06 00:00:00-05:00          1   Aquarius  Sagittarius    Gemini
# 1928-01-09 00:00:00-05:00          0   Aquarius  Sagittarius    Cancer
#
#                              Mars_Sign Mercury_Sign Jupiter_Sign Venus_Sign  \
# Date
# 1928-01-03 00:00:00-05:00      Scorpio  Sagittarius       Pisces    Scorpio
# 1928-01-04 00:00:00-05:00      Scorpio  Sagittarius       Pisces    Scorpio
# 1928-01-05 00:00:00-05:00      Scorpio  Sagittarius       Pisces    Scorpio
# 1928-01-06 00:00:00-05:00      Scorpio  Sagittarius       Pisces    Scorpio
# 1928-01-09 00:00:00-05:00  Sagittarius  Sagittarius       Pisces    Scorpio
#
#                           Saturn_Sign Rahu_Sign Ketu_Sign
# Date
# 1928-01-03 00:00:00-05:00     Scorpio    Taurus   Scorpio
# 1928-01-04 00:00:00-05:00     Scorpio    Taurus   Scorpio
# 1928-01-05 00:00:00-05:00     Scorpio    Taurus   Scorpio
# 1928-01-06 00:00:00-05:00     Scorpio    Taurus   Scorpio
# 1928-01-09 00:00:00-05:00     Scorpio    Taurus   Scorpio

# %%
# filter change_pc == 1 
import pandas as pd
cdff = df[df['change_pc'] == 1]
cdff.head()
# group by Ascendant and sum of change_pc
cordata = cdff.groupby('Ascendant')['change_pc'].sum()
# rename  Ascendant as sign_name
cordata = cordata.rename_axis('sign_name')
# rename series to ascendant
cordata = cordata.rename('ascendant')
cordata
# Out:
# sign_name
# Aquarius        679
# Aries           740
# Cancer         1353
# Capricorn       773
# Gemini         1584
# Leo            1409
# Libra          1251
# Pisces          672
# Sagittarius    1074
# Scorpio         923
# Taurus         1087
# Virgo          1360
# Name: ascendant, dtype: int64

# %%
platnets = [
    'Moon_Sign', 'Sun_Sign', 'Mars_Sign', 'Mercury_Sign',
    'Jupiter_Sign', 'Venus_Sign', 'Saturn_Sign', 'Rahu_Sign', 'Ketu_Sign'
]

final_df =cordata.copy()

for planet in platnets:
    # group by planet and sum of change_pc
    pdata = cdff.groupby(planet)['change_pc'].sum()
    # rename planet as sign_name
    pdata = pdata.rename_axis('sign_name')
    # rename series to planet
    pdata = pdata.rename(planet)
    # join cordata and pdata on sign_name
    final_df = pd.concat([final_df, pdata], axis=1)
# sdata = cdff.groupby('Moon_Sign')['change_pc'].sum()
# sdata = sdata.rename_axis('sign_name')
# sdata = sdata.rename('Moon_Sign')

# join cordata and sdata on sign_name
final_df
# Out:
#              ascendant  Moon_Sign  Sun_Sign  Mars_Sign  Mercury_Sign  \
# sign_name
# Aquarius           679       1074      1009        842          1087
# Aries              740       1113      1110        937           986
# Cancer            1353       1106      1118       1342          1029
# Capricorn          773       1047      1094        895          1103
# Gemini            1584       1037      1140       1263          1015
# Leo               1409       1102      1105       1292          1107
# Libra             1251       1103      1088       1130          1136
# Pisces             672       1052      1068        908          1013
# Sagittarius       1074       1082      1002        940          1165
# Scorpio            923       1035      1029       1034          1164
# Taurus            1087       1059      1097       1083           975
# Virgo             1360       1095      1045       1239          1125
#
#              Jupiter_Sign  Venus_Sign  Saturn_Sign  Rahu_Sign  Ketu_Sign
# sign_name
# Aquarius              975         928         1385       1111       1027
# Aries                1113        1019          864       1219       1062
# Cancer               1104        1001          902       1024       1013
# Capricorn             982        1172         1382       1013       1024
# Gemini               1118        1153          865       1041       1052
# Leo                  1098        1267          923       1027       1111
# Libra                1131        1187         1099       1062       1219
# Pisces               1001        1215         1017       1218       1002
# Sagittarius          1024         964         1473       1052       1041
# Scorpio              1126         974         1204        963       1173
# Taurus               1119        1109          816       1173        963
# Virgo                1114         916          975       1002       1218

# %%
# plot sign_name vs all planets sum of change_pc
import seaborn as sns
import matplotlib.pyplot as plt
final_df.reset_index(inplace=True)
plt.figure(figsize=(12, 8))
sns.lineplot(data=final_df, x='sign_name', y='ascendant', marker='o', label='Ascendant')
sns.lineplot(data=final_df, x='sign_name', y='Moon_Sign', marker='o', label='Moon_Sign')
sns.lineplot(data=final_df, x='sign_name', y='Sun_Sign', marker='o', label='Sun_Sign')
sns.lineplot(data=final_df, x='sign_name', y='Mars_Sign',   marker='o', label='Mars_Sign')
sns.lineplot(data=final_df, x='sign_name', y='Mercury_Sign', marker='o', label='Mercury_Sign')
sns.lineplot(data=final_df, x='sign_name', y='Jupiter_Sign', marker='o', label='Jupiter_Sign')
sns.lineplot(data=final_df, x='sign_name', y='Venus_Sign', marker='o', label='Venus_Sign')
sns.lineplot(data=final_df, x='sign_name', y='Saturn_Sign', marker='o', label='Saturn_Sign')
sns.lineplot(data=final_df, x='sign_name', y='Rahu_Sign', marker='o', label='Rahu_Sign')
sns.lineplot(data=final_df, x='sign_name', y='Ketu_Sign', marker='o', label='Ketu_Sign')
plt.title('Sum of change_pc by Astrological Signs')
# Out:
# Text(0.5, 1.0, 'Sum of change_pc by Astrological Signs')

# %%
final_df.reset_index(inplace=True)
fig, axes = plt.subplots(5, 2, figsize=(16, 20))
axes = axes.flatten()

columns_to_plot = ['ascendant', 'Moon_Sign', 'Sun_Sign', 'Mars_Sign', 'Mercury_Sign', 
                   'Jupiter_Sign', 'Venus_Sign', 'Saturn_Sign', 'Rahu_Sign', 'Ketu_Sign']

for idx, col in enumerate(columns_to_plot):
    final_df.plot(x='sign_name', y=col, kind='bar', ax=axes[idx], legend=False, color='steelblue')
    axes[idx].set_title(f'{col} - Sum of change_pc by Signs')
    axes[idx].set_xlabel('Astrological Signs')
    axes[idx].set_ylabel('Sum of change_pc')
    axes[idx].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
columns_to_plot = ['ascendant', 'Moon_Sign', 'Sun_Sign', 'Mars_Sign', 'Mercury_Sign', 
                   'Jupiter_Sign', 'Venus_Sign', 'Saturn_Sign', 'Rahu_Sign', 'Ketu_Sign']

# # final_df 
for col in columns_to_plot:
    print(f"Top 3 signs for {col}:")
    print(final_df[col].sort_values(ascending=False).head(3))
# Out:
# Top 3 signs for ascendant:
# 4     1584
# 5     1409
# 11    1360
# Name: ascendant, dtype: int64
# Top 3 signs for Moon_Sign:
# 1    1113
# 2    1106
# 6    1103
# Name: Moon_Sign, dtype: int64
# Top 3 signs for Sun_Sign:
# 4    1140
# 2    1118
# 1    1110
# Name: Sun_Sign, dtype: int64
# Top 3 signs for Mars_Sign:
# 2    1342
# 5    1292
# 4    1263
# Name: Mars_Sign, dtype: int64
# Top 3 signs for Mercury_Sign:
# 8    1165
# 9    1164
# 6    1136
# Name: Mercury_Sign, dtype: int64
# Top 3 signs for Jupiter_Sign:
# 6     1131
# 9     1126
# 10    1119
# Name: Jupiter_Sign, dtype: int64
# Top 3 signs for Venus_Sign:
# 5    1267
# 7    1215
# 6    1187
# Name: Venus_Sign, dtype: int64
# Top 3 signs for Saturn_Sign:
# 8    1473
# 0    1385
# 3    1382
# Name: Saturn_Sign, dtype: int64
# Top 3 signs for Rahu_Sign:
# 1     1219
# 7     1218
# 10    1173
# Name: Rahu_Sign, dtype: int64
# Top 3 signs for Ketu_Sign:
# 6     1219
# 11    1218
# 9     1173
# Name: Ketu_Sign, dtype: int64

# %%
import swisseph as swe
from datetime import datetime
from typing import Dict, Any, Optional
import pytz

# Zodiac signs
SIGNS = [
    'Aries', 'Taurus', 'Gemini', 'Cancer', 'Leo', 'Virgo',
    'Libra', 'Scorpio', 'Sagittarius', 'Capricorn', 'Aquarius', 'Pisces'
]

# Planet constants and names
PLANETS = [
    (swe.SUN, 'Sun'),
    (swe.MOON, 'Moon'),
    (swe.MERCURY, 'Mercury'),
    (swe.VENUS, 'Venus'),
    (swe.MARS, 'Mars'),
    (swe.JUPITER, 'Jupiter'),
    (swe.SATURN, 'Saturn'),
    (swe.URANUS, 'Uranus'),
    (swe.NEPTUNE, 'Neptune'),
    (swe.PLUTO, 'Pluto'),
    (swe.MEAN_NODE, 'Rahu'),
]


def get_planetary_positions(
    local_datetime: datetime,
    latitude: float,
    longitude: float,
    timezone: str = 'UTC',
    sidereal: bool = True,
    ayanamsa: int = swe.SIDM_LAHIRI
) -> Dict[str, Any]:
    """
    Calculate planetary positions for a given date, time, and location.
    
    Args:
        local_datetime: Local date and time (naive datetime)
        latitude: Location latitude (positive for North, negative for South)
        longitude: Location longitude (positive for East, negative for West)
        timezone: Timezone string (e.g., 'Asia/Kolkata', 'America/New_York')
        sidereal: If True, use sidereal zodiac (Vedic). If False, use tropical (Western)
        ayanamsa: Ayanamsa type for sidereal calculation (default: Lahiri)
    
    Returns:
        Dictionary containing datetime info, location, ayanamsa, ascendant, and planetary positions
    """
    
    # Convert local time to UTC
    local_tz = pytz.timezone(timezone)
    if local_datetime.tzinfo is None:
        local_dt = local_tz.localize(local_datetime)
    else:
        local_dt = local_datetime
    utc_dt = local_dt.astimezone(pytz.UTC)
    
    # Calculate Julian Day
    hour_decimal = utc_dt.hour + utc_dt.minute / 60 + utc_dt.second / 3600
    julian_day = swe.julday(utc_dt.year, utc_dt.month, utc_dt.day, hour_decimal)
    
    # Set sidereal mode if required
    if sidereal:
        swe.set_sid_mode(ayanamsa)
        calc_flag = swe.FLG_SIDEREAL
        ayanamsa_value = swe.get_ayanamsa(julian_day)
        zodiac_system = 'Sidereal'
    else:
        calc_flag = 0
        ayanamsa_value = 0.0
        zodiac_system = 'Tropical'
    
    # Initialize result dictionary
    result = {
        'input': {
            'local_datetime': local_datetime.strftime('%Y-%m-%d %H:%M:%S'),
            'timezone': timezone,
            'latitude': latitude,
            'longitude': longitude,
        },
        'calculated': {
            'utc_datetime': utc_dt.strftime('%Y-%m-%d %H:%M:%S'),
            'julian_day': julian_day,
            'zodiac_system': zodiac_system,
            'ayanamsa': {
                'name': 'Lahiri' if ayanamsa == swe.SIDM_LAHIRI else 'Other',
                'value': round(ayanamsa_value, 4)
            } if sidereal else None,
        },
        'ascendant': {},
        'planets': {}
    }
    
    # Calculate Ascendant (Lagna)
    try:
        houses = swe.houses(julian_day, latitude, longitude, b'P')  # Placidus house system
        ascendant_longitude = houses[1][0]  # Ascendant is first element
        
        if sidereal:
            ascendant_longitude = (ascendant_longitude - ayanamsa_value) % 360
        
        result['ascendant'] = _format_position(ascendant_longitude, 'Ascendant')
    except Exception as e:
        result['ascendant'] = {'error': str(e)}
    
    # Calculate planetary positions
    for planet_id, planet_name in PLANETS:
        try:
            calc_result = swe.calc_ut(julian_day, planet_id, calc_flag)
            lon = calc_result[0][0]
            speed = calc_result[0][3]  # Daily speed for retrograde check
            
            planet_data = _format_position(lon, planet_name)
            planet_data['speed'] = round(speed, 4)
            planet_data['retrograde'] = speed < 0
            
            result['planets'][planet_name] = planet_data
            
            # Calculate Ketu (opposite to Rahu)
            if planet_id == swe.MEAN_NODE:
                ketu_lon = (lon + 180) % 360
                ketu_data = _format_position(ketu_lon, 'Ketu')
                ketu_data['speed'] = round(speed, 4)
                ketu_data['retrograde'] = True  # Nodes are always retrograde
                result['planets']['Ketu'] = ketu_data
                
        except Exception as e:
            result['planets'][planet_name] = {'error': str(e)}
    
    return result


def _format_position(longitude: float, body_name: str) -> Dict[str, Any]:
    """Format longitude into zodiac position details."""
    sign_num = int(longitude // 30)
    degree_in_sign = longitude % 30
    degrees = int(degree_in_sign)
    minutes = int((degree_in_sign - degrees) * 60)
    seconds = int(((degree_in_sign - degrees) * 60 - minutes) * 60)
    
    return {
        'longitude': round(longitude, 4),
        'sign': SIGNS[sign_num],
        'sign_num': sign_num + 1,  # 1-indexed (Aries = 1)
        'degrees': degrees,
        'minutes': minutes,
        'seconds': seconds,
        'formatted': f"{degrees}° {minutes}' {seconds}\" {SIGNS[sign_num]}"
    }


def print_positions(positions: Dict[str, Any]) -> None:
    """Pretty print the planetary positions."""
    print("\n" + "=" * 70)
    print("PLANETARY POSITIONS")
    print("=" * 70)
    
    # Input details
    inp = positions['input']
    calc = positions['calculated']
    print(f"\nLocal Time:  {inp['local_datetime']} ({inp['timezone']})")
    print(f"UTC Time:    {calc['utc_datetime']}")
    print(f"Location:    {inp['latitude']}° N, {inp['longitude']}° E")
    print(f"Julian Day:  {calc['julian_day']}")
    print(f"Zodiac:      {calc['zodiac_system']}")
    
    if calc['ayanamsa']:
        print(f"Ayanamsa:    {calc['ayanamsa']['name']} ({calc['ayanamsa']['value']}°)")
    
    # Ascendant
    print("\n" + "-" * 70)
    asc = positions['ascendant']
    if 'error' not in asc:
        print(f"{'ASCENDANT (Lagna)':<20} {asc['formatted']:<25} {asc['longitude']:>10.4f}°")
    print("-" * 70)
    
    # Planets
    print(f"{'Planet':<20} {'Position':<25} {'Longitude':>10}  {'Retro'}")
    print("-" * 70)
    
    for planet_name, data in positions['planets'].items():
        if 'error' not in data:
            retro = 'R' if data['retrograde'] else ''
            print(f"{planet_name:<20} {data['formatted']:<25} {data['longitude']:>10.4f}°  {retro}")
    
    print("=" * 70)

# %%
# us longitude and latitude  timezone America/New_York

# tomorrow date at 9:30
cur_date  = datetime.now()
local_dt = datetime(cur_date.year, cur_date.month, cur_date.day + 1, 9, 30, 0)  # Tomorrow at 9:30 AM
print(f"Local DateTime for Calculation: {local_dt}")

lat = 40.7128
lon = -74.0060
tz = 'America/New_York'
positions = get_planetary_positions(
    local_datetime=local_dt,
    latitude=lat,
    longitude=lon,
    timezone=tz,
    sidereal=True
)
print(f"Ascendant: {positions['ascendant']['sign']}")

for key, value in positions['planets'].items():
        data = f"{key}: {value['sign']}"
        print(f" {key}: {value['sign']}")


spx_dates_df
# Out:
# Local DateTime for Calculation: 2025-12-15 09:30:00
# Ascendant: Capricorn
#  Sun: Scorpio
#  Moon: Libra
#  Mercury: Scorpio
#  Venus: Scorpio
#  Mars: Sagittarius
#  Jupiter: Gemini
#  Saturn: Pisces
#  Uranus: Taurus
#  Neptune: Pisces
#  Pluto: Capricorn
#  Rahu: Aquarius
#  Ketu: Leo
#                                   Open         High          Low        Close  \
# Date
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-09 00:00:00-05:00    17.500000    17.500000    17.500000    17.500000
# ...                                ...          ...          ...          ...
# 2025-12-08 00:00:00-05:00  6875.200195  6878.270020  6827.189941  6846.509766
# 2025-12-09 00:00:00-05:00  6840.609863  6864.919922  6837.430176  6840.509766
# 2025-12-10 00:00:00-05:00  6833.490234  6900.669922  6824.689941  6886.680176
# 2025-12-11 00:00:00-05:00  6861.299805  6903.459961  6833.450195  6901.000000
# 2025-12-12 00:00:00-05:00  6886.850098  6899.850098  6801.790039  6827.410156
#
#                                Volume  change_pc    Ascendant     Sun_Sign  \
# Date
# 1928-01-03 00:00:00-05:00           0          1    Capricorn  Sagittarius
# 1928-01-04 00:00:00-05:00           0          0    Capricorn  Sagittarius
# 1928-01-05 00:00:00-05:00           0          0    Capricorn  Sagittarius
# 1928-01-06 00:00:00-05:00           0          1     Aquarius  Sagittarius
# 1928-01-09 00:00:00-05:00           0          0     Aquarius  Sagittarius
# ...                               ...        ...          ...          ...
# 2025-12-08 00:00:00-05:00  4757130000          0  Sagittarius      Scorpio
# 2025-12-09 00:00:00-05:00  4508050000          0  Sagittarius      Scorpio
# 2025-12-10 00:00:00-05:00  5526570000          1  Sagittarius      Scorpio
# 2025-12-11 00:00:00-05:00  5021060000          1  Sagittarius      Scorpio
# 2025-12-12 00:00:00-05:00  3194992806          0  Sagittarius      Scorpio
#
#                           Moon_Sign    Mars_Sign Mercury_Sign Jupiter_Sign  \
# Date
# 1928-01-03 00:00:00-05:00    Taurus      Scorpio  Sagittarius       Pisces
# 1928-01-04 00:00:00-05:00    Taurus      Scorpio  Sagittarius       Pisces
# 1928-01-05 00:00:00-05:00    Taurus      Scorpio  Sagittarius       Pisces
# 1928-01-06 00:00:00-05:00    Gemini      Scorpio  Sagittarius       Pisces
# 1928-01-09 00:00:00-05:00    Cancer  Sagittarius  Sagittarius       Pisces
# ...                             ...          ...          ...          ...
# 2025-12-08 00:00:00-05:00    Cancer  Sagittarius      Scorpio       Gemini
# 2025-12-09 00:00:00-05:00    Cancer  Sagittarius      Scorpio       Gemini
# 2025-12-10 00:00:00-05:00       Leo  Sagittarius      Scorpio       Gemini
# 2025-12-11 00:00:00-05:00       Leo  Sagittarius      Scorpio       Gemini
# 2025-12-12 00:00:00-05:00     Virgo  Sagittarius      Scorpio       Gemini
#
#                           Venus_Sign Saturn_Sign Rahu_Sign Ketu_Sign
# Date
# 1928-01-03 00:00:00-05:00    Scorpio     Scorpio    Taurus   Scorpio
# 1928-01-04 00:00:00-05:00    Scorpio     Scorpio    Taurus   Scorpio
# 1928-01-05 00:00:00-05:00    Scorpio     Scorpio    Taurus   Scorpio
# 1928-01-06 00:00:00-05:00    Scorpio     Scorpio    Taurus   Scorpio
# 1928-01-09 00:00:00-05:00    Scorpio     Scorpio    Taurus   Scorpio
# ...                              ...         ...       ...       ...
# 2025-12-08 00:00:00-05:00    Scorpio      Pisces  Aquarius       Leo
# 2025-12-09 00:00:00-05:00    Scorpio      Pisces  Aquarius       Leo
# 2025-12-10 00:00:00-05:00    Scorpio      Pisces  Aquarius       Leo
# 2025-12-11 00:00:00-05:00    Scorpio      Pisces  Aquarius       Leo
# 2025-12-12 00:00:00-05:00    Scorpio      Pisces  Aquarius       Leo
#
# [24604 rows x 16 columns]

# %%
print(f"Ascendant: {positions['ascendant']['sign']}")
conditions = []
conditions.append(f"Ascendant == '{positions['ascendant']['sign']}'")
for key, value in positions['planets'].items():
    # We wrap the column name in backticks `{key}_Sign` to handle spaces (e.g., "North Node")
    # if(key not in  ['Uranus','Neptune','Pluto','Rahu','Ketu','Saturn','Jupiter','Mercury','Venus','Mars']):
    # if(key not in  ['Uranus','Neptune','Pluto','Rahu','Ketu','Saturn','Jupiter','Mercury','Venus','Mars','Sun']):
    if(key  in  ['Saturn']):

    # if(key not in  ['Uranus','Neptune','Pluto','Rahu','Ketu','Saturn','Jupiter','Venus','Ascendant']):
        conditions.append(f"{key}_Sign == '{value['sign']}'")

# 2. Join them with ' and '
strq = " and ".join(conditions)

print(f"Query String: {conditions}")

print(f"Query String: {strq}")

# 3. Only run query if string is not empty
if strq:
    filtered_df = spx_dates_df.query(strq)
else:
    filtered_df = spx_dates_df # or empty df, depending on your logic
    print("No conditions provided.")

filtered_df
# Out:
# Ascendant: Capricorn
# Query String: ["Ascendant == 'Capricorn'", "Saturn_Sign == 'Pisces'"]
# Query String: Ascendant == 'Capricorn' and Saturn_Sign == 'Pisces'
#                                  Open        High         Low       Close  \
# Date
# 1937-12-13 00:00:00-05:00   10.740000   10.740000   10.740000   10.740000
# 1937-12-14 00:00:00-05:00   10.830000   10.830000   10.830000   10.830000
# 1937-12-15 00:00:00-05:00   10.910000   10.910000   10.910000   10.910000
# 1937-12-16 00:00:00-05:00   11.080000   11.080000   11.080000   11.080000
# 1937-12-17 00:00:00-05:00   11.000000   11.000000   11.000000   11.000000
# ...                               ...         ...         ...         ...
# 1997-12-26 00:00:00-05:00  932.700012  939.989990  932.700012  936.460022
# 1997-12-29 00:00:00-05:00  936.460022  953.950012  936.460022  953.349976
# 1997-12-30 00:00:00-05:00  953.349976  970.840027  953.349976  970.840027
# 1997-12-31 00:00:00-05:00  970.840027  975.020020  967.409973  970.429993
# 1998-01-02 00:00:00-05:00  970.429993  975.039978  965.729980  975.039978
#
#                               Volume  change_pc  Ascendant     Sun_Sign  \
# Date
# 1937-12-13 00:00:00-05:00          0          0  Capricorn      Scorpio
# 1937-12-14 00:00:00-05:00          0          1  Capricorn      Scorpio
# 1937-12-15 00:00:00-05:00          0          1  Capricorn  Sagittarius
# 1937-12-16 00:00:00-05:00          0          1  Capricorn  Sagittarius
# 1937-12-17 00:00:00-05:00          0          0  Capricorn  Sagittarius
# ...                              ...        ...        ...          ...
# 1997-12-26 00:00:00-05:00  154900000          1  Capricorn  Sagittarius
# 1997-12-29 00:00:00-05:00  443160000          1  Capricorn  Sagittarius
# 1997-12-30 00:00:00-05:00  499500000          1  Capricorn  Sagittarius
# 1997-12-31 00:00:00-05:00  467280000          0  Capricorn  Sagittarius
# 1998-01-02 00:00:00-05:00  366730000          1  Capricorn  Sagittarius
#
#                              Moon_Sign  Mars_Sign Mercury_Sign Jupiter_Sign  \
# Date
# 1937-12-13 00:00:00-05:00        Aries   Aquarius  Sagittarius    Capricorn
# 1937-12-14 00:00:00-05:00        Aries   Aquarius  Sagittarius    Capricorn
# 1937-12-15 00:00:00-05:00        Aries   Aquarius  Sagittarius    Capricorn
# 1937-12-16 00:00:00-05:00       Taurus   Aquarius  Sagittarius    Capricorn
# 1937-12-17 00:00:00-05:00       Taurus   Aquarius  Sagittarius    Capricorn
# ...                                ...        ...          ...          ...
# 1997-12-26 00:00:00-05:00      Scorpio  Capricorn      Scorpio    Capricorn
# 1997-12-29 00:00:00-05:00  Sagittarius  Capricorn      Scorpio    Capricorn
# 1997-12-30 00:00:00-05:00  Sagittarius  Capricorn      Scorpio    Capricorn
# 1997-12-31 00:00:00-05:00    Capricorn  Capricorn      Scorpio    Capricorn
# 1998-01-02 00:00:00-05:00     Aquarius  Capricorn      Scorpio    Capricorn
#
#                           Venus_Sign Saturn_Sign Rahu_Sign Ketu_Sign
# Date
# 1937-12-13 00:00:00-05:00    Scorpio      Pisces   Scorpio    Taurus
# 1937-12-14 00:00:00-05:00    Scorpio      Pisces   Scorpio    Taurus
# 1937-12-15 00:00:00-05:00    Scorpio      Pisces   Scorpio    Taurus
# 1937-12-16 00:00:00-05:00    Scorpio      Pisces   Scorpio    Taurus
# 1937-12-17 00:00:00-05:00    Scorpio      Pisces   Scorpio    Taurus
# ...                              ...         ...       ...       ...
# 1997-12-26 00:00:00-05:00  Capricorn      Pisces       Leo  Aquarius
# 1997-12-29 00:00:00-05:00  Capricorn      Pisces       Leo  Aquarius
# 1997-12-30 00:00:00-05:00  Capricorn      Pisces       Leo  Aquarius
# 1997-12-31 00:00:00-05:00  Capricorn      Pisces       Leo  Aquarius
# 1998-01-02 00:00:00-05:00  Capricorn      Pisces       Leo  Aquarius
#
# [98 rows x 16 columns]

# %%
filtered_df.groupby('change_pc')['change_pc'].sum()
# Out:
# change_pc
# 0     0
# 1    51
# Name: change_pc, dtype: int64
